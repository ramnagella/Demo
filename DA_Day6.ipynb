# %% [markdown]
# <a href="https://colab.research.google.com/github/ramnagella/Demo/blob/master/DA_Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas baics--12-08-2024
#discussed fo far adding rows and columns

import pandas as pd
data ={
    "Duration":{
        "1":30,
        "2":40,
        "3":50,
        "4":55,
        "5":60
    },
    "Pulse":{
        "1":110,
        "2":120,
        "3":130,
        "4":140,
        "5":150
    },
    "Maxpulse":{
        "1":130,
        "2":140,
        "3":150,
        "4":160,
        "5":170
    },
    "Calories":{
        "1":409,
        "2":479,
        "3":340,
        "4":282,
        "5":406
    }
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        60    150       170       406

# %%
df.loc[6]=[100,200,300,400]
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        60    150       170       406
# 6       100    200       300       400

# %%
df.index=['value1','value2','value3','value4','value5','value6']
df
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location  Location    Name  \
# value1        30    110       130       409  123       Hyd       Hyd     Ram
# value2        40    120       140       479  132  Banglore  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     Delhi     NaN
# value6       100    200       300       400  178      Pune      Pune   Krish
#
#        contact_numbers index
# value1           12345     a
# value2           45678     b
# value3           54321     c
# value4          345632     d
# value5          652324     e
# value6           87657     f

# %%
df['BP']=['123','132','143','145','156','178']
df
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location    Name  \
# value1        30    110       130       409  123       Hyd     Ram
# value2        40    120       140       479  132  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     NaN
# value6       100    200       300       400  178      Pune   Krish
#
#        contact_numbers index
# value1           12345     a
# value2           45678     b
# value3           54321     c
# value4          345632     d
# value5          652324     e
# value6           87657     f

# %%
name={409:'Ram',479:'Shatha',340:'Vamsi',282:'Sai',75:'Bhavani',400:'kiran',400:'Krish'}
df['Name']=df['Calories'].map(name)
df
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location    Name  \
# value1        30    110       130       409  123       Hyd     Ram
# value2        40    120       140       479  132  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     NaN
# value6       100    200       300       400  178      Pune   Krish
#
#        contact_numbers index
# value1           12345     a
# value2           45678     b
# value3           54321     c
# value4          345632     d
# value5          652324     e
# value6           87657     f

# %%
Location=['Hyd','Banglore','Chennai','Mumbai','Delhi','Pune']
df.insert(5,'Location',Location,True)
df
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location  Location    Name  \
# value1        30    110       130       409  123       Hyd       Hyd     Ram
# value2        40    120       140       479  132  Banglore  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     Delhi     NaN
# value6       100    200       300       400  178      Pune      Pune   Krish
#
#        contact_numbers index
# value1           12345     a
# value2           45678     b
# value3           54321     c
# value4          345632     d
# value5          652324     e
# value6           87657     f

# %%
df=df.assign(contact_numbers=['12345','45678','54321','345632','652324','87657'])
df
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location  Location    Name  \
# value1        30    110       130       409  123       Hyd       Hyd     Ram
# value2        40    120       140       479  132  Banglore  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     Delhi     NaN
# value6       100    200       300       400  178      Pune      Pune   Krish
#
#        contact_numbers index
# value1           12345     a
# value2           45678     b
# value3           54321     c
# value4          345632     d
# value5          652324     e
# value6           87657     f

# %%
df.drop('index',axis=1,inplace=True)
df
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location  Location    Name  \
# value1        30    110       130       409  123       Hyd       Hyd     Ram
# value2        40    120       140       479  132  Banglore  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     Delhi     NaN
# value6       100    200       300       400  178      Pune      Pune   Krish
#
#        contact_numbers
# value1           12345
# value2           45678
# value3           54321
# value4          345632
# value5          652324
# value6           87657

# %%
#Data Transformation---
'''
----.rename(column,index)
----.sort_values(by,axis,ascending)
----.sort_index(axis,ascending)
----.reset_index(
-----astype(dtype)
-----apply(func,axis)
-----.map(arg)

'''
#Rename ---index,column or both
df.rename(index={'value1':'Case1','value2':'Case2'},columns={'contact_numbers':'phone_number'})
# Out:
#         Duration  Pulse  Maxpulse  Calories   BP  Location  Location    Name  \
# Case1         30    110       130       409  123       Hyd       Hyd     Ram
# Case2         40    120       140       479  132  Banglore  Banglore  Shatha
# value3        50    130       150       340  143   Chennai   Chennai   Vamsi
# value4        55    140       160       282  145    Mumbai    Mumbai     Sai
# value5        60    150       170       406  156     Delhi     Delhi     NaN
# value6       100    200       300       400  178      Pune      Pune   Krish
#
#        phone_number
# Case1         12345
# Case2         45678
# value3        54321
# value4       345632
# value5       652324
# value6        87657

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories', 'BP', 'Location',
#        'Location', 'Name', 'contact_numbers'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Duration',
#  'Pulse',
#  'Maxpulse',
#  'Calories',
#  'BP',
#  'Location',
#  'Location',
#  'Name',
#  'contact_numbers']

# %%
col_names=[col for col in df.columns] #in for loop df.columns o/p is by default in list format .We no need to mention list
col_names
# Out:
# ['Duration',
#  'Pulse',
#  'Maxpulse',
#  'Calories',
#  'BP',
#  'Location',
#  'Location',
#  'Name',
#  'contact_numbers']

# %%
for col_name in df.columns:
    print(col_name)
# Out:
# Duration
# Pulse
# Maxpulse
# Calories
# BP
# Location
# Location
# Name
# contact_numbers

# %%
#data type --astype
df.dtypes
# Out:
# Duration            int64
# Pulse               int64
# Maxpulse            int64
# Calories            int64
# BP                 object
# Location           object
# Location           object
# Name               object
# contact_numbers    object
# dtype: object

# %%
df.astype({'Pulse':'float64','Maxpulse':'float64'})
df.dtypes
# Out:
# Duration            int64
# Pulse               int64
# Maxpulse            int64
# Calories            int64
# BP                 object
# Location           object
# Location           object
# Name               object
# contact_numbers    object
# dtype: object

# %%
df=df.astype({'Pulse':'float64','Maxpulse':'float64'})
df.dtypes
# Out:
# Duration             int64
# Pulse              float64
# Maxpulse           float64
# Calories             int64
# BP                  object
# Location            object
# Location            object
# Name                object
# contact_numbers     object
# dtype: object

# %%
#apply()---axis 0 or 2
#df.apply(finc,axis=0,raw=True)#series format boolean value false
df.apply(max,axis=1)
# Out:
# 1    409
# 2    479
# 3    340
# 4    282
# 5    406
# dtype: int64

# %%
df.apply(max,axis=0)
# Out:
# Duration     60
# Pulse       150
# Maxpulse    170
# Calories    479
# dtype: int64

# %%
import pandas as pd
data ={
    "Duration":{
        "1":30,
        "2":40,
        "3":50,
        "4":55,
        "5":60
    },
    "Pulse":{
        "1":110,
        "2":120,
        "3":130,
        "4":140,
        "5":150
    },
    "Maxpulse":{
        "1":130,
        "2":140,
        "3":150,
        "4":160,
        "5":170
    },
    "Calories":{
        "1":409,
        "2":479,
        "3":340,
        "4":282,
        "5":406
    }
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        60    150       170       406

# %%
def time_convert(x):
  return x/60
#df['Duration']=df['Duration'].apply(time_convert)
result=df.applymap(time_convert)
result
#if you want to make operations in horizontal manner use axis=1 one record in all columns axis =0 means one column and in all rows
# Out:
# /tmp/ipython-input-6-3423340295.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   result=df.applymap(time_convert)
#    Duration     Pulse  Maxpulse  Calories
# 1  0.500000  1.833333  2.166667  6.816667
# 2  0.666667  2.000000  2.333333  7.983333
# 3  0.833333  2.166667  2.500000  5.666667
# 4  0.916667  2.333333  2.666667  4.700000
# 5  1.000000  2.500000  2.833333  6.766667

# %%
#how to apply for only duration value not for all
result=df['Duration']=df['Duration'].apply(time_convert)
result
#df
# Out:
# 1    0.500000
# 2    0.666667
# 3    0.833333
# 4    0.916667
# 5    1.000000
# Name: Duration, dtype: float64

# %%
df['Duration']=df['Duration'].apply(time_convert)
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1  0.008333    110       130       409
# 2  0.011111    120       140       479
# 3  0.013889    130       150       340
# 4  0.015278    140       160       282
# 5  0.016667    150       170       406

# %%
def convert_sec(x,sec):
  return x * sec
result=df.apply(convert_sec,axis=1,sec=60)
result
# Out:
#    Duration   Pulse  Maxpulse  Calories
# 1  0.500000  6600.0    7800.0   24540.0
# 2  0.666667  7200.0    8400.0   28740.0
# 3  0.833333  7800.0    9000.0   20400.0
# 4  0.916667  8400.0    9600.0   16920.0
# 5  1.000000  9000.0   10200.0   24360.0

# %%
'''
sort_values(by,axis,ascending)---based on values sort the values row wise or column wise
sort_index(axis,ascending)---based on index
'''
df.sort_values(by='Duration',ascending=False)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 5  0.016667    150       170       406
# 4  0.015278    140       160       282
# 3  0.013889    130       150       340
# 2  0.011111    120       140       479
# 1  0.008333    110       130       409

# %%
df.sort_values(by='Pulse',axis=0,ascending=False)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 5  0.016667    150       170       406
# 4  0.015278    140       160       282
# 3  0.013889    130       150       340
# 2  0.011111    120       140       479
# 1  0.008333    110       130       409

# %%
df.sort_values(by='Pulse',axis=0,ascending=True)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1  0.008333    110       130       409
# 2  0.011111    120       140       479
# 3  0.013889    130       150       340
# 4  0.015278    140       160       282
# 5  0.016667    150       170       406

# %%
df.sort_values(by='Pulse',axis=0,ascending=False,ignore_index=True)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0  0.016667    150       170       406
# 1  0.015278    140       160       282
# 2  0.013889    130       150       340
# 3  0.011111    120       140       479
# 4  0.008333    110       130       409

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#    Pulse  Maxpulse  Duration  Calories
# 1    110       130  0.008333       409
# 2    120       140  0.011111       479
# 3    130       150  0.013889       340
# 4    140       160  0.015278       282
# 5    150       170  0.016667       406

# %%
df.sort_index()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1  0.008333    110       130       409
# 2  0.011111    120       140       479
# 3  0.013889    130       150       340
# 4  0.015278    140       160       282
# 5  0.016667    150       170       406

# %%
df.sort_index(ascending=False)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 5  0.016667    150       170       406
# 4  0.015278    140       160       282
# 3  0.013889    130       150       340
# 2  0.011111    120       140       479
# 1  0.008333    110       130       409

# %%
df.sort_index(level='2')
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1  0.008333    110       130       409
# 2  0.011111    120       140       479
# 3  0.013889    130       150       340
# 4  0.015278    140       160       282
# 5  0.016667    150       170       406

# %%
df.sort_index(level='2',ascending=False)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 5  0.016667    150       170       406
# 4  0.015278    140       160       282
# 3  0.013889    130       150       340
# 2  0.011111    120       140       479
# 1  0.008333    110       130       409

# %%
df.sort_index(key=lambda x:x.str.lower())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1  0.008333    110       130       409
# 2  0.011111    120       140       479
# 3  0.013889    130       150       340
# 4  0.015278    140       160       282
# 5  0.016667    150       170       406

# %%
df.sort_index(key=lambda x:x.str.len())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1  0.008333    110       130       409
# 2  0.011111    120       140       479
# 3  0.013889    130       150       340
# 4  0.015278    140       160       282
# 5  0.016667    150       170       406

# %%
df.sort_index(axis=1)
# Out:
#    Calories  Duration  Maxpulse  Pulse
# 1       409  0.008333       130    110
# 2       479  0.011111       140    120
# 3       340  0.013889       150    130
# 4       282  0.015278       160    140
# 5       406  0.016667       170    150

# %%
#File Handling relative path
with open('file.txt','r') as f:
  f.read()

# %%
import os
os.getcwd()
#this command will work from persnal laptop or desktophre will not work because we are running the programs in colab
# Out:
# '/content'

# %%
#File Handling
with open('C:\\Users\\Ramudu.nagella\\Desktop\\AI and ML\\file.txt','r') as f:
  f.read()

# %%
#csv,tsv,txt files---read_csv() to read and to_csv() to write in pandas
#if the file size is in MB we can go with Pandas and if it is GB or TB better to use Pyspark
#Pandas is data analysis tool not processing tool
#txt files are in unstructured format it is not easy to process or analyse using  pandas
'''
Data Export---
1 csv
2.text+w---with the help of write mode operation
3.str(df)----text file --string data frame format

'''
df.to_csv('details.csv')

# %%
#ignoring index storing only data
df.to_csv('details.csv',index=False)

# %%
pd.read_csv('details.csv')
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        30    110       130       409
# 1        40    120       140       479
# 2        50    130       150       340
# 3        55    140       160       282
# 4        60    150       170       406

# %%
pd.read_csv('details.csv',index_col=[1])
# Out:
#        Duration  Maxpulse  Calories
# Pulse
# 110          30       130       409
# 120          40       140       479
# 130          50       150       340
# 140          55       160       282
# 150          60       170       406

# %%
#default csv file separator is comma delimiters there are many
#create a csv file with # separator like name,age,city columns
#and read it
pd.read_csv('details.csv',sep='#')

# %%
pd.read_csv('details.csv',index_col=[0])
# Out:
#           Pulse  Maxpulse  Calories
# Duration
# 30          110       130       409
# 40          120       140       479
# 50          130       150       340
# 55          140       160       282
# 60          150       170       406

# %%
#Converting DataFrame into text format
#create txt file as below
'''
avg.txt
virat    rahul    rohit
45.5555  54.2323  55.56565
45.5555  54.2323  55.56565
45.5555  54.2323  55.56565
'''
f=open('avg.txt','r')
print(f.read())
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-2057461507.py in <cell line: 0>()
#       1 #Converting DataFrame into text format
# ----> 2 df
#
# NameError: name 'df' is not defined

# %%
with open('avg.txt','r') as f:
  print(f.read())

# %%
pd.read_csv('avg.txt',sep='\t')

# %%
f=open('avg.txt','w')
f.write('virat\trahul\trohit\n')
f.write('45.5555\t54.2323\t55.56565\n')
f.close()

# %%
f=open('avg.txt','w')
f.write(str(df))
f.close()

# %%
f=open('avg.txt','w')
f.write(df)
f.close()

# %%
pd.read_csv('avg.txt')
#bbeter to avoid txt during Data analysis

# %%
def convert_sec(x,sec):
  return x * sec
result=df.apply(convert_sec,axis=1,sec=60)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-545964686.py in <cell line: 0>()
#       1 def convert_sec(x,sec):
#       2   return x * sec
# ----> 3 result=df.apply(convert_sec,axis=1,sec=60)
#       4 result
#
# NameError: name 'df' is not defined
