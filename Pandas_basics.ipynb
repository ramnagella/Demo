# %% [markdown]
# <a href="https://colab.research.google.com/github/ramnagella/Demo/blob/master/Pandas_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Agenda###----Window functuons ---cumsum(),cummax(),cumprod(),cummin(),rolling(windows=2),
reshape---##stack(),unstack(),pivot(),pivit table discussion
----##melt(),crosstab()
----##lead,lag,diff,shift(),rank()
----

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("hello Python")
# Out:
# hello Python

# %%
##Window functions-----on 23_Aug-2023
import pandas as pd
import numpy as np
df=pd.DataFrame({
    'a':[1,2,3,4,5,6,7,1,9,10],
    'b':[10,np.nan,np.nan,20,np.nan,np.nan,30,30,30,np.nan]
})
df
# Out:
#     a     b
# 0   1  10.0
# 1   2   NaN
# 2   3   NaN
# 3   4  20.0
# 4   5   NaN
# 5   6   NaN
# 6   7  30.0
# 7   1  30.0
# 8   9  30.0
# 9  10   NaN

# %%
df['a.cumsum()']=df['a'].cumsum()
#df['a.cummax()']=df['a'].cummax()
#df['a.cumprod()']=df['a'].cumprod()
#df['a.cummin()']=df['a'].cummin()
df
# Out:
#     a     b  a.cumsum()  a.cummax()  a.cumprod()  a.cummin()
# 0   1  10.0           1           1            1           1
# 1   2   NaN           3           2            2           1
# 2   3   NaN           6           3            6           1
# 3   4  20.0          10           4           24           1
# 4   5   NaN          15           5          120           1
# 5   6   NaN          21           6          720           1
# 6   7  30.0          28           7         5040           1
# 7   1  30.0          29           7         5040           1
# 8   9  30.0          38           9        45360           1
# 9  10   NaN          48          10       453600           1
