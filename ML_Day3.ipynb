# %% [markdown]
# <a href="https://colab.research.google.com/github/ramnagella/Demo/blob/master/ML_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ML_Day3---23-10-2024 Session
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', index_col=0)
df
#it will teake first column as index
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1-927953954.py in <cell line: 0>()
#       1 #ML_Day3---23-10-2024 Session
#       2 import pandas as pd
# ----> 3 df=pd.read_csv('Sample_data.csv',sep='#', index_col=0)
#       4 df
#       5 #it will teake first column as index
#
# ...

# %%
#how to upload files from local machine into Colab
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5496fecf-9e8c-44c2-8a49-4676d787f46e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5496fecf-9e8c-44c2-8a49-4676d787f46e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', index_col=0)
df
#it will teake first column as index
# Out:
#         Age      City,`
# Name
# Ram      47  Hyderabad,
# Shatha   13   Banglore,
# Vamsi    16    Chennai,
# Kiran    32      Delhi,

# %%
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', usecols=['Name','Age'],index_col=0)
df
# Out:
#         Age
# Name
# Ram      47
# Shatha   13
# Vamsi    16
# Kiran    32

# %%
df.dtypes
# Out:
# Age    int64
# dtype: object

# %%
#Changing the data type of columsn from float to int
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', dtype={'Age':'int64'})
df

# %%
#Skipping the some rows and read
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', dtype={'Age':'int64'},skiprows=2)
df
# Out:
#   Shatha  13 Banglore,
# 0  Vamsi  16  Chennai,
# 1  Kiran  32    Delhi,

# %%
#Skipping the some rows and read and addthe column names
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', dtype={'Age':'int64'},skiprows=2,names=['Name','Age','City'])
df
# Out:
#      Name  Age       City
# 0  Shatha   13  Banglore,
# 1   Vamsi   16   Chennai,
# 2   Kiran   32     Delhi,

# %%
#Limitig to read the no of rows like only one row to read
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', dtype={'Age':'int64'},skiprows=2,names=['Name','Age','City'],nrows=1)
df
# Out:
#      Name  Age       City
# 0  Shatha   13  Banglore,

# %%
#Adding another date column
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#', dtype={'Age':'int64'},skiprows=2,names=['Name','Age','City'],nrows=1,parse_dates=['Date'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-7-3261686940.py in <cell line: 0>()
#       1 #Adding another date column
#       2 import pandas as pd
# ----> 3 df=pd.read_csv('Sample_data.csv',sep='#', dtype={'Age':'int64'},skiprows=2,names=['Name','Age','City'],nrows=1,parse_dates=['Date'])
#       4 df
#
# ...

# %%
#Skipping the some rows and read and addthe column names
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#')
df
# Out:
#      Name  Age      City,`
# 0     Ram   47  Hyderabad,
# 1  Shatha   13   Banglore,
# 2   Vamsi   16    Chennai,
# 3   Kiran   32      Delhi,

# %%
#Adding another column DOB
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#')
df['DOB']=['02-02-1980','09-07-2012','25-11-2007','21-12-2006']
df
# Out:
#      Name  Age      City,`         DOB
# 0     Ram   47  Hyderabad,  02-02-1980
# 1  Shatha   13   Banglore,  09-07-2012
# 2   Vamsi   16    Chennai,  25-11-2007
# 3   Kiran   32      Delhi,  21-12-2006

# %%
#updating into csv file
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#')
df['DOB']=['02-02-1980','09-07-2012','25-11-2007','21-12-2006']
df.to_csv('Updated_data.csv')

# %%
#ignoring the index label
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#')
df['DOB']=['02-02-1980','09-07-2012','25-11-2007','21-12-2006']
df.to_csv('Updated_data.csv',index=False)

# %%
df.to_csv('Updated_data.csv',index=False,header=False)
df
#it will display the df without header check the syntax
# Out:
#      Name  Age      City,`         DOB
# 0     Ram   47  Hyderabad,  02-02-1980
# 1  Shatha   13   Banglore,  09-07-2012
# 2   Vamsi   16    Chennai,  25-11-2007
# 3   Kiran   32      Delhi,  21-12-2006

# %%
#Adding another column DOB
import pandas as pd
df=pd.read_csv('Sample_data.csv',sep='#')
df['DOB']=['02-02-1980','09-07-2012','25-11-2007','21-12-2006']
df['Salary']=[1000.34252,2000.3535336,3000.644647,4000.646464]
df
# Out:
#      Name  Age      City,`         DOB       Salary
# 0     Ram   47  Hyderabad,  02-02-1980  1000.342520
# 1  Shatha   13   Banglore,  09-07-2012  2000.353534
# 2   Vamsi   16    Chennai,  25-11-2007  3000.644647
# 3   Kiran   32      Delhi,  21-12-2006  4000.646464

# %%
import pandas as pd
df.to_csv('Updated_data.csv',float_format='%.2f')
df
#Check the result buy opening the file Updated_data.csv file in colab
# Out:
#      Name  Age      City,`         DOB       Salary
# 0     Ram   47  Hyderabad,  02-02-1980  1000.342520
# 1  Shatha   13   Banglore,  09-07-2012  2000.353534
# 2   Vamsi   16    Chennai,  25-11-2007  3000.644647
# 3   Kiran   32      Delhi,  21-12-2006  4000.646464

# %%
import pandas as pd
df_json=pd.read_json('Sample.json')
df_json
# Out:
#    id    name  age         city
# 0   1     Ram   30     New York
# 1   2  Shatha   13     Banglore
# 2   3   Vamsi   17  Los Angeles
# 3   4   Kiran   30    Hyderabad

# %%
import os
import pandas as pd
df_json=pd.read_json('Sample.json')
df_json
# Out:
#    id    name  age         city
# 0   1     Ram   30     New York
# 1   2  Shatha   13     Banglore
# 2   3   Vamsi   17  Los Angeles
# 3   4   Kiran   30    Hyderabad

# %%
import pandas as pd
df_json=pd.read_json('Sample.json',orient='records')
df_json
#same result will get bcause default json format is orient
# Out:
#    id    name  age         city
# 0   1     Ram   30     New York
# 1   2  Shatha   13     Banglore
# 2   3   Vamsi   17  Los Angeles
# 3   4   Kiran   30    Hyderabad

# %%
df_json.to_json('Sample_new.json')
#the data is comma separated

# %%
df_json.to_json('Sample_new.json',orient='columns')
#the data is comma separated

# %%
df_json.to_json('Sample_new.json',orient='split')
#the data is comma separated

# %%
df_json.to_json('Sample_new.json',orient='index')
#the data is comma separated

# %%
df_json.to_json('Sample_new.json',orient='index',indent=2)
#the data is two spaces separated indent =2 means

# %%
#Reading Wxcel files
import pandas as pd
df_excel=pd.read_excel('sample_data.xlsx')
df_excel
# Out:
#            Unnamed: 0
# 0       Name#Age#City
# 1    Ram#47#Hyderabad
# 2  Shatha#13#Banglore
# 3    Vamsi#16#Chennai
# 4      Kiran#32#Delhi
# 5   Sam#23#Vijayawada
# 6     Reena#24#London

# %%
#Reading Wxcel files
import pandas as pd
df_excel=pd.read_excel('sample_data.xlsx',sep='#')
df_excel
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-1852225300.py in <cell line: 0>()
#       1 #Reading Wxcel files
#       2 import pandas as pd
# ----> 3 df_excel=pd.read_excel('sample_data.xlsx',sep='#')
#       4 df_excel
#
# TypeError: read_excel() got an unexpected keyword argument 'sep'

# %%
# !pip install openpyxl

# %%
#Reading Wxcel files
import pandas as pd
df_excel=pd.read_excel('sample_data.xlsx')
df_excel
# Out:
#            Unnamed: 0
# 0       Name#Age#City
# 1    Ram#47#Hyderabad
# 2  Shatha#13#Banglore
# 3    Vamsi#16#Chennai
# 4      Kiran#32#Delhi
# 5   Sam#23#Vijayawada
# 6     Reena#24#London

# %%
#Reading second sheet of excel files using sheet_name option
#we can use options like usecols,dtypes,nrows,skiprows,similar to_excel same attribute we can use
#to_excel(sheet_name,index,columns,engine like openpyxl,xlsxwritten)

import pandas as pd
df_excel=pd.read_excel('sample_sales.xlsx',sheet_name='SalesOrders')
df_excel
# Out:
#     Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN            OrderDate     Region        Rep       Item
# 1          NaN  2024-06-01 00:00:00       East      Jones     Pencil
# 2          NaN            1/23/2024    Central     Kivell     Binder
# 3          NaN  2024-09-02 00:00:00    Central    Jardine     Pencil
# 4          NaN            2/26/2024    Central       Gill        Pen
# 5          NaN            3/15/2024       West    Sorvino     Pencil
# 6          NaN  2024-01-04 00:00:00       East      Jones     Binder
# 7          NaN            4/18/2024    Central    Andrews     Pencil
# 8          NaN  2024-05-05 00:00:00    Central    Jardine     Pencil
# 9          NaN            5/22/2024       West   Thompson     Pencil
# 10         NaN  2024-08-06 00:00:00       East      Jones     Binder
# 11         NaN            6/25/2024    Central     Morgan     Pencil
# 12         NaN  2024-12-07 00:00:00       East     Howard     Binder
# ...

# %%
#to read sql we can use read_sql,ti write we can use to_sql
#import sqlite3
import sqlite3
import pandas as pd
conn=sqlite3.connect('sample.db')
sql_df=pd.read_sql('select * from sample_data',conn)
sql_df
conn.close()
#to_sql('sample_data,conn,if_exists='append' or replace or index=False also we can use )
