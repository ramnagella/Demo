# %% [markdown]
# <a href="https://colab.research.google.com/github/ramnagella/Demo/blob/master/DA_Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DA_Day5---09-08-2024---Pandas Basics
print("hello")
# Out:
# hello

# %%
import pandas as pd
data ={
    "Duration":{
        "1":30,
        "2":40,
        "3":50,
        "4":55,
        "5":60
    },
    "Pulse":{
        "1":110,
        "2":120,
        "3":130,
        "4":140,
        "5":150
    },
    "Maxpulse":{
        "1":130,
        "2":140,
        "3":150,
        "4":160,
        "5":170
    },
    "Calories":{
        "1":409,
        "2":479,
        "3":340,
        "4":282,
        "5":406
    }
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        60    150       170       406

# %%
#Here need keep the sample.json file inthe location and read
import pandas as pd
df=pd.read_json('sample.json')
df

# %%
#Changing the index values
import pandas as pd
df=pd.read_json('sample.json')
df.index=['value1','value2','value3','value4','value5','value6']
df

# %%
#Accesing particular value like duration and value3 based on label using at attribute
df.at['value3','duration']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-1255620533> in <cell line: 0>()
# ...

# %%
df.at['value4','pulse']

# %%
#Accesing particular value like duration and value3 based on index position using iat attribute
df.iat['3','1']

# %%
#DataFrame manipulation ---Structure --like adding and removing rows and columns.updating values in rows/columns
'''
Row
----Drop rows
----drop()
----.index  index position---based on the index postion drop the rows
----filtering !=,==,>,<
'''
import pandas as pd
data ={
    "Duration":{
        "1":30,
        "2":40,
        "3":50,
        "4":55,
        "5":60
    },
    "Pulse":{
        "1":110,
        "2":120,
        "3":130,
        "4":140,
        "5":150
    },
    "Maxpulse":{
        "1":130,
        "2":140,
        "3":150,
        "4":160,
        "5":170
    },
    "Calories":{
        "1":409,
        "2":479,
        "3":340,
        "4":282,
        "5":406
    }
}
df=pd.DataFrame(data)
df.index=['value1','value2','value3','value4','value5']
print(df)
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value2        40    120       140       479
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
df.drop('value2')
#it will not delete original dataframe.deletes only in runtime
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
df
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value2        40    120       140       479
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
#to delete in the original DataFrame run the below statement
df=df.drop('value2')

# %%
#to delete in the original DataFrame run the below statement using function
df.drop('value2',inplace=True)

# %%
#if you want ti delete multiple rows permanently in  original DF
df.drop(['value1','value3'],inplace=True)

# %%
#if you want ti delete multiple s pcolumns permanently in  original DF
#DF is 2-D data structure
'''
row axis ==0
column axis ==1
default axis is ZERO(8)
'''
df.drop(['Duration','Pulse'],axis=1,inplace=True)

# %%
#delete column
df.index['0']
#need to check the error.in the down it is working fine
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-1282107511> in <cell line: 0>()
#       1 #delete column
# ----> 2 df.index['0']
#       3 #need to check the error
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5414                     )
#    5415
# -> 5416         result = getitem(key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
df.drop(df.index[0])
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value2        40    120       140       479
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
print(df.index[0])
# Out:
# value1

# %%
df.index[0]
# Out:
# 'value1'

# %%
df.drop(df.index[-1])
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value2        40    120       140       479
# value3        50    130       150       340
# value4        55    140       160       282

# %%
df['Duration']!=40
# Out:
# value1     True
# value2    False
# value3     True
# value4     True
# value5     True
# Name: Duration, dtype: bool

# %%
df[df['Duration']!=40]
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
#if you want to drop the records after filtering in original DF
df=df[df['Duration']!=40]

# %%
#dispalyig in reverse
df[:,-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), -1)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-5-366711368> in <cell line: 0>()
#       1 #dispalyig in reverse
# ----> 2 df[:,-1]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
# ...

# %%
#deleting columns
df
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value2        40    120       140       479
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
df.drop('Pulse')
#key error because by defalut it will take axis =0  or drop method row automatically searching row by row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4095418920> in <cell line: 0>()
# ----> 1 df.drop('Pulse')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.drop('Pulse',axis=1)
# Out:
#         Duration  Maxpulse  Calories
# value1        30       130       409
# value2        40       140       479
# value3        50       150       340
# value4        55       160       282
# value5        60       170       406

# %%
df
# Out:
#         Duration  Pulse  Maxpulse  Calories
# value1        30    110       130       409
# value2        40    120       140       479
# value3        50    130       150       340
# value4        55    140       160       282
# value5        60    150       170       406

# %%
#dropping multiple columns
df.drop(['Duration','Pulse'],axis=1)
# Out:
#         Maxpulse  Calories
# value1       130       409
# value2       140       479
# value3       150       340
# value4       160       282
# value5       170       406

# %%
df.drop(['Duration':'Maxpulse'],axis=1)
#it will not work
# Out:
#   File "<ipython-input-16-3362611836>", line 1
#     df.drop(['Duration':'Maxpulse'],axis=1)
#                        ^
# SyntaxError: invalid syntax

# %%
df.drop(columns=['Duration','Maxpulse'])
#dropping columns without axis attribute
# Out:
#         Pulse  Calories
# value1    110       409
# value2    120       479
# value3    130       340
# value4    140       282
# value5    150       406

# %%
df.drop(index=['value1','value3'],columns='Duration')
# Out:
#         Pulse  Maxpulse  Calories
# value2    120       140       479
# value4    140       160       282
# value5    150       170       406

# %%
#want to fetch/select  particular column without loc or iloc
df.Pulse
# Out:
# value1    110
# value2    120
# value3    130
# value4    140
# value5    150
# Name: Pulse, dtype: int64

# %%
#want to individual values without at or iat below is old technique to fecth the values
#it is deprecated one after 1.x Pandas introduced loc or iloc or at and iat
df.Pulse[1]
# Out:
# <ipython-input-24-1703416312>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.Pulse[1]
# np.int64(120)

# %%
#which one is best one to extract the values
#Attribute or loc or iloc ----
import pandas as pd
data ={
    "Duration":{
        "1":30,
        "2":40,
        "3":50,
        "4":55,
        "5":60
    },
    "Pulse":{
        "1":110,
        "2":120,
        "3":130,
        "4":140,
        "5":150
    },
    "Maxpulse":{
        "1":130,
        "2":140,
        "3":150,
        "4":160,
        "5":170
    },
    "Calories":{
        "1":409,
        "2":479,
        "3":340,
        "4":282,
        "5":406
    }
}
df=pd.DataFrame(data)
#df.index=['value1','value2','value3','value4','value5']
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        60    150       170       406

# %%
df[1]
#here will get key error because in this case label and index position values are same
#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-3006201197> in <cell line: 0>()
# ----> 1 df[1]
#
# ...

# %%
#To come out fromt he above error that is the reason we are going with loc,iloc,at iat
df.iloc[0]
# Out:
# Duration     30
# Pulse       110
# Maxpulse    130
# Calories    409
# Name: 1, dtype: int64

# %%
#fetching column lables/values for particular column and printing as list case
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
list(df.columns)
# Out:
# ['Duration', 'Pulse', 'Maxpulse', 'Calories']

# %%
list(df.index)
# Out:
# ['1', '2', '3', '4', '5']

# %%
#fetch particular columns labels/values and print into list format
li=[]
for values in df['Pulse']:
  li.append(values)
  print(li)
# Out:
# [110]
# [110, 120]
# [110, 120, 130]
# [110, 120, 130, 140]
# [110, 120, 130, 140, 150]

# %%
#fetch particular columns labels/values and print into list format
li=[]
for values in df['Pulse']:
  li.append(values)
print(li)
# Out:
# [110, 120, 130, 140, 150]

# %%
#using list comprehension
li=[values for values in df['Pulse']]
print(li)
# Out:
# [110, 120, 130, 140, 150]

# %%
#to check the time it takes to execute
# %%time
li=[]
for values in df['Pulse']:
  li.append(values)
print(li)
# Out:
# [110, 120, 130, 140, 150]
# CPU times: user 1.13 ms, sys: 0 ns, total: 1.13 ms
# Wall time: 1.05 ms

# %%
# %%time
#using list comprehension
li=[values for values in df['Pulse']]
print(li)
# Out:
# [110, 120, 130, 140, 150]
# CPU times: user 260 µs, sys: 26 µs, total: 286 µs
# Wall time: 292 µs

# %%
#want to update teh values in a row
df.iloc[4]=[45,55,65,75]

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        45     55        65        75

# %%
#want ti update particular value in row and column---task

# %%
#adding new row to df will get error here
df.iloc[6]=[100,200,300,400]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-2039523953> in <cell line: 0>()
#       1 #adding new row to df will get error here
# ----> 2 df.iloc[6]=[100,200,300,400]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     906             key = self._check_deprecated_callable_usage(key, maybe_callable)
#     907         indexer = self._get_setitem_indexer(key)
# --> 908         self._has_valid_setitem_indexer(key)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1644             elif is_integer(i):
#    1645                 if i >= len(ax):
# -> 1646                     raise IndexError("iloc cannot enlarge its target object")
# ...

# %%
df.loc[6]=[100,200,300,400]
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        30    110       130       409
# 2        40    120       140       479
# 3        50    130       150       340
# 4        55    140       160       282
# 5        45     55        65        75
# 6       100    200       300       400

# %%
#adding a column--
'''
dict,
list,---most of them will use this
insert()-- method,
assign()-- method
'''
df['BP']=['123','132','143','145','156','178']
df
# Out:
#    Duration  Pulse  Maxpulse  Calories   BP
# 1        30    110       130       409  123
# 2        40    120       140       479  132
# 3        50    130       150       340  143
# 4        55    140       160       282  145
# 5        45     55        65        75  156
# 6       100    200       300       400  178

# %%
name={409:'Ram',479:'Shatha',340:'Vamsi',282:'Sai',75:'Bhavani',400:'kiran',400:'Krish'}
df['Name']=df['Calories'].map(name)
df
#adding another new column name based on the other column values like calories or pulse
# Out:
#    Duration  Pulse  Maxpulse  Calories   BP     Name
# 1        30    110       130       409  123      Ram
# 2        40    120       140       479  132   Shatha
# 3        50    130       150       340  143    Vamsi
# 4        55    140       160       282  145      Sai
# 5        45     55        65        75  156  Bhavani
# 6       100    200       300       400  178    Krish

# %%
#insert()---desited location add column
Location=['Hyd','Banglore','Chennai','Mumbai','Delhi','Pune']
df.insert(5,'Location',Location,True)
df
# Out:
#    Duration  Pulse  Maxpulse  Calories   BP  Location     Name
# 1        30    110       130       409  123       Hyd      Ram
# 2        40    120       140       479  132  Banglore   Shatha
# 3        50    130       150       340  143   Chennai    Vamsi
# 4        55    140       160       282  145    Mumbai      Sai
# 5        45     55        65        75  156     Delhi  Bhavani
# 6       100    200       300       400  178      Pune    Krish
